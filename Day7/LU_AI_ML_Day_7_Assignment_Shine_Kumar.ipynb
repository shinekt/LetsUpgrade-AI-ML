# %% [markdown]
# # Question 1:

# %% [markdown]
# Attach the dataset and mentioned problem statement below,
# * A sizable department has to be maintained, for the purposes of recruiting new talent
# * More often than not, the new employees have to be trained for the job and/or given time to
# acclimatize themselves to the company
# * Hence, the management has contracted an HR analytics firm to understand what factors they
# should focus on, in order to curb attrition.
# * In other words, they want to know what changes they should make to their workplace, in order to
# get most of their employees to stay.
# * Also, they want to know which of these variables is most important and needs to be addressed
# right away.

# %%
import pandas as pd

#Load the CSV datafile
data = pd.read_csv("general_data.csv")

df = pd.DataFrame(data)

#check the first 5 entries of the datafram
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
#check all the columns of the data frame
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# The following attributes governs the employees leaving the company
#
# * Age
# * DistanceFromHome
# * MonthlyIncome
# * PercentSalaryHike
# * StockOptionLevel
# * TotalWorkingYears
# * YearsAtCompany
# * YearsSinceLastPromotion

# %%
# create a new dataframe as per the identified important parameters
new_df = df[['Age','DistanceFromHome','MonthlyIncome','NumCompaniesWorked','PercentSalaryHike','StockOptionLevel','TotalWorkingYears','YearsAtCompany','YearsSinceLastPromotion']]

#Diplay first 5 rows
new_df.head()
# Out:
#    Age  DistanceFromHome  MonthlyIncome  NumCompaniesWorked  \
# 0   51                 6         131160                 1.0
# 1   31                10          41890                 0.0
# 2   32                17         193280                 1.0
# 3   38                 2          83210                 3.0
# 4   32                10          23420                 4.0
#
#    PercentSalaryHike  StockOptionLevel  TotalWorkingYears  YearsAtCompany  \
# 0                 11                 0                1.0               1
# 1                 23                 1                6.0               5
# 2                 15                 3                5.0               5
# 3                 11                 3               13.0               8
# 4                 12                 2                9.0               6
#
#    YearsSinceLastPromotion
# 0                        0
# 1                        1
# 2                        0
# 3                        7
# ...

# %%
from matplotlib import pyplot as plt

f, (subplt2,subplt3) = plt.subplots(1,2)

#scatter plot to check total working years of an employee against the percentage of salary hike
subplt2.scatter(new_df["TotalWorkingYears"],new_df["PercentSalaryHike"])

#scatter plot of check years since the last promotion of an employee against percentage of salary hike
subplt3.scatter(new_df["YearsSinceLastPromotion"],new_df["PercentSalaryHike"])

# %% [markdown]
# Analysis from the graph and the immediate action items
#
# Immediate action items
#
# * Fig1 : y axis holds the "percentage salary hike" against x axis, which holds "total working years". Here, we can see the maximum percentage of hike is given to enployees with total experience within 10 years. This should be changed to include senior employees to increase the percentage of salary hike.
# * Fig2 : y axis holds the "percentage salary hike" against x asix, which holds "years since last promotion". Here, we can see the number of employes who were awarded a higher hike percentage were promoted within 5 years. This should be revised to include the senior employees to either include promotion or salary hike
